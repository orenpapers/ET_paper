# %%
# !pwd
# Out:
# /export/home/orenkobo

# %%
import scipy
def draw_stars_box(regr_acc_l, rand_acc_l, stat_test = 'wilcoxon', suf="",show=True, ax=None, reverse_labels = False, alternative='two-sided',
                   verbose = True, ylabel = "CORRELATION", title = "",xlabels = ['Actual','Shuffled']):
    def stars(p):
        if p < 0.0001:
            return "****"
        elif (p < 0.001):
            return "***"
        elif (p < 0.01):
            return "**"
        elif (p < 0.05):
            return "*"
        else:
            return "-"
    print("Hwwlp")
    #https://github.com/jbmouret/matplotlib_for_papers
    if stat_test == 'wilcoxon':
        z, p = scipy.stats.wilcoxon(regr_acc_l, rand_acc_l, alternative=alternative)
    if stat_test == 'mannwhittney':
        z, p = scipy.stats.mannwhitneyu(regr_acc_l, rand_acc_l, alternative=alternative)
    p_value = p * 2
    stars_txt = stars(p)
    s = f"{suf} : {stat_test}: z = {z} , p = {p} "
    if verbose:
        print(s)

    fig = figure(figsize=(3,3))
    if ax is None:
        ax = fig.add_subplot(111)

    bp = ax.boxplot([regr_acc_l, rand_acc_l])
    params = {
        'axes.labelsize': 8,
        'font.size': 8,
        'legend.fontsize': 10,
        'xtick.labelsize': 10,
        'ytick.labelsize': 10,
        'text.usetex': False,
        'figure.figsize': [5, 8]
    }
    rcParams.update(params)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    ax.tick_params(axis='x', direction='out', size=15)
    ax.tick_params(axis='y', length=0)
    ax.grid(axis='y', color="0.9", linestyle='-', linewidth=1)
    ax.set_axisbelow(True)
    # colors, as before
    colors = Set2_7.mpl_colors

    for i in range(0, len(bp['boxes'])):
        bp['boxes'][i].set_color(colors[i])
        # we have two whiskers!
        bp['whiskers'][i*2].set_color(colors[i])
        bp['whiskers'][i*2 + 1].set_color(colors[i])
        bp['whiskers'][i*2].set_linewidth(2)
        bp['whiskers'][i*2 + 1].set_linewidth(2)
        # fliers
        # (set allows us to set many parameters at once)
        bp['fliers'][i].set(markerfacecolor=colors[i],
                            marker='o', alpha=0.75, markersize=6,
                            markeredgecolor='none')
        bp['medians'][i].set_color('black')
        bp['medians'][i].set_linewidth(3)
        # and 4 caps to remove
        for c in bp['caps']:
            c.set_linewidth(0)
    for i in range(len(bp['boxes'])):
        box = bp['boxes'][i]
        box.set_linewidth(0)
        boxX = []
        boxY = []
        for j in range(5):
            boxX.append(box.get_xdata()[j])
            boxY.append(box.get_ydata()[j])
            boxCoords = list(zip(boxX,boxY))
            boxPolygon = Polygon(boxCoords, facecolor = colors[i], linewidth=0)
            ax.add_patch(boxPolygon)

    if reverse_labels:
        xlabels.reverse()
    ax.set_xticklabels(xlabels, fontsize=15)


    y_max = np.max(np.concatenate((regr_acc_l, rand_acc_l)))
    y_min = np.min(np.concatenate((regr_acc_l, rand_acc_l)))

    ax.annotate("", xy=(1, y_max), xycoords='data',
                xytext=(2, y_max), textcoords='data',
                arrowprops=dict(arrowstyle="-", ec='#aaaaaa',
                                connectionstyle="bar,fraction=0.2"))
    ax.text(1.5, y_max + abs(y_max - y_min)*0.2, stars_txt,
            horizontalalignment='center',
            verticalalignment='center')
    # ax.set_suptitle(f"Per iteration accuracy {suf} - {p}", fontsize = 12)
    # ax.subplots_adjust(left=0.2)
    ax.set_ylabel(ylabel, fontsize=16)
    ax.set_title(title)
    if show:
        plt.show()


    return s, ax

# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2022-07-14 09:40:15.336085

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
from tensorflow.python.keras import backend as K
print(K._get_available_gpus())
# Out:
# Num GPUs Available:  1
# ['/device:GPU:0']

# %%
import joblib

import tensorflow as tf
import numpy as np
import datetime
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from sklearn.preprocessing import LabelEncoder
scale_col = "x_gaze_location_standard_scaled"

def apply_phq_cutoff(df , neg_phq_cutoff, pos_phq_cutoff):
    df["phq_binary_label"] = [0.0 if x <= neg_phq_cutoff else 1.0 if x >= pos_phq_cutoff else "other" for x in df.phq_score]
    df = df[df.phq_binary_label!= 'other']
    return df


def get_timecols_df_for_DL(#fn ="/Users/orenkobo/Desktop/PhD_new/repos/HebLingStudy/notebooks/df.csv",
        fn,
                           scale_col = scale_col):

    import string, re
    print(f"{datetime.datetime.now()} Reading csv from {fn}")
    df = pd.read_csv(fn,
                     index_col=None,
                     converters={#'alephbert_enc': eval,
                         scale_col : eval,
                         # 'x_gaze_location_minmax_scaled' : eval,
                         # 'x_gaze_location_standard_scaled' : eval,
                         # 'target_word_x_range' : eval
                         # 'phq_label': bool
                     })
    print(df.shape)


    df = df[df.Sentence_type != 'F'].reset_index(drop=True)


    id_cols = ["phq_score","phq_group","Subject", "Sentence_type",
               "sentence_pupil_diameter_mean","set_num"]
    # vec_size = 3500
    # new_colname = f"x_gaze_location_{vec_size}"
    cols = [f"timepoint#{i}" for i in range(875)]
    # df[new_colname] = df["x_gaze_location_standard_scaled"].apply(lambda x : x[:vec_size])
    timeseries_df = pd.DataFrame(data = df[scale_col].to_list() , columns = cols)
    timeseries_df[id_cols] = df[id_cols]
    timeseries_df = timeseries_df.iloc[:,200:]
    cols = [x for x in timeseries_df.columns if "timepoint" in x]
    return timeseries_df, cols

# %%
import pandas as pd
d = {}
df_fn = "/export/home/orenkobo/Aim1/paper_analysis/Artifacts/df_new_full__unsegmented_alldata_new_FINAL_paparanalysis.csv"
# df_fn = "/Users/orenkobo/Desktop/PhD/HebLingStudy/ts_data/Artifacts2/df_new_full__unsegmented_alldata_new_FINAL.csv"
# et_scale_col = "x_gaze_location_rescaled"
et_scale_col = "x_gaze_location_standard_scaled"
override_cutoff = [7,8]
df, timepoint_cols = get_timecols_df_for_DL(fn =df_fn, scale_col = scale_col)
df = apply_phq_cutoff(df,
                      neg_phq_cutoff = override_cutoff[0],
                      pos_phq_cutoff = override_cutoff[1])


cond_df = pd.get_dummies(df['Sentence_type'])
cond_cols = cond_df.columns.tolist()
df = pd.concat([df, cond_df],axis=1)
df = df.reset_index(drop=True)
df['encoded_cond'] = LabelEncoder().fit_transform(df['Sentence_type'])

df
# Out:
# 2022-07-14 09:40:20.456237 Reading csv from /export/home/orenkobo/Aim1/paper_analysis/Artifacts/df_new_full__unsegmented_alldata_new_FINAL_paparanalysis.csv
# (9696, 32)
#       timepoint#200  timepoint#201  timepoint#202  timepoint#203  \
# 0          1.248853       1.242846       1.250856       1.257864
# 1         -0.605603      -0.604602      -0.602600      -0.590588
# 2          0.127316       0.133326       0.121306       0.099268
# 3         -1.144312      -1.155340      -1.149325      -1.117245
# 4         -1.554332      -1.571359      -1.577369      -1.608418
# ...             ...            ...            ...            ...
# 3227      -1.686416      -1.706449      -1.697434      -2.352531
# 3228       0.985337       0.997349       0.986338       0.976329
# 3229       1.002969       1.014985       0.504330       0.345126
# 3230       1.745621       1.753631       1.758638       1.737610
# 3231       0.597177       0.605189       0.584156       0.580149
#
#       timepoint#204  timepoint#205  timepoint#206  timepoint#207  \
# 0          1.246851       1.239843       1.238841       1.250856
# 1         -1.061065      -1.648661      -1.700713      -1.695708
# 2          0.104277       0.115296       0.122307       0.124311
# 3         -1.106217      -1.129275      -1.135290      -1.111230
# 4         -1.600405      -1.571359      -1.558338      -1.560341
# ...             ...            ...            ...            ...
# 3227      -2.500779      -2.447690      -2.421646      -2.419643
# 3228       0.983335       0.991343       0.990342       0.994346
# 3229       0.339118       0.340120       0.351134       0.363149
# 3230       1.736609       1.735608       1.736609       1.741616
# 3231       0.589164       0.593170       0.607193       0.593170
#
#       timepoint#208  timepoint#209  ...  Subject  Sentence_type  \
# 0          1.242846       1.239843  ...        3              A
# 1         -1.703717      -1.710724  ...        3              B
# 2          0.135330       0.161374  ...        3              D
# 3         -1.109224      -1.127270  ...        3              A
# 4         -1.565349      -1.573362  ...        3              B
# ...             ...            ...  ...      ...            ...
# 3227      -2.425653      -2.450695  ...      139              D
# 3228       0.975328       0.977330  ...      139              D
# 3229       0.364150       0.377167  ...      139              A
# 3230       1.322060       1.367120  ...      139              C
# 3231       0.599180       0.602185  ...      139              C
#
#       sentence_pupil_diameter_mean  set_num  phq_binary_label  A  B  C  D  \
# 0                      5110.630668       17               0.0  1  0  0  0
# 1                      4974.146741        5               0.0  0  1  0  0
# 2                      4739.278462       12               0.0  0  0  0  1
# 3                      4775.260020        6               0.0  1  0  0  0
# 4                      4746.720839       26               0.0  0  1  0  0
# ...                            ...      ...               ... .. .. .. ..
# 3227                   5117.994088        0               1.0  0  0  0  1
# 3228                   4995.187626       15               1.0  0  0  0  1
# 3229                   4934.199434       27               1.0  1  0  0  0
# 3230                   5056.427875        4               1.0  0  0  1  0
# 3231                   5069.907967       13               1.0  0  0  1  0
#
#       encoded_cond
# 0                0
# 1                1
# 2                3
# 3                0
# 4                1
# ...            ...
# 3227             3
# 3228             3
# 3229             0
# 3230             2
# 3231             2
#
# [3232 rows x 687 columns]

# %%
print(df[timepoint_cols].shape)
print(df[timepoint_cols].dropna().shape)
df[timepoint_cols] = df[timepoint_cols].ffill()
print(df[timepoint_cols].shape)
# Out:
# (3232, 675)
# (1427, 675)
# (3232, 675)

# %%
def generate_3d_ds(df, feats = timepoint_cols):
    data_3d = []

    labels = []
    # print(f"{datetime.datetime.now()} - DS generated Start")
    for idx , row in df.iterrows():
        # if (idx % 500) == 0:
        #     print(idx)
        l = []
        for col in feats:
            l.append([row[col]] + [row['encoded_cond']])
        data_3d.append(l)
        labels.append(row["phq_binary_label"])
    X_input = np.asarray(data_3d)
    X_input_reshaped = np.swapaxes(X_input,1,2)
    # print(f"{datetime.datetime.now()} - DS generated Done")

    return X_input_reshaped, labels

# %%
def calc_per_subj_pred(pred, n=32):
    if type(pred) != list:
        pred = [x[0] for x in pred]
    c = [pred[i * n:(i + 1) * n] for i in range((len(pred) + n - 1) // n )]
    l = pd.DataFrame(c).mean(axis=1)
    return l

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=16, restore_best_weights=True)]

def train_fold(X_train, y_train, X_val, y_val, voc_size=4, nepochs=20):

    inp1 = layers.Input(shape=(1, 675))  # TensorShape([None, 2, 100])
    inp2 = layers.Input(shape=(1, 675))  # TensorShape([None, 1, 100])
    x2 = layers.Embedding(input_dim=voc_size, output_dim=8)(inp2)  # TensorShape([None, 1, 100, 8])
    x2_reshaped = tf.transpose(tf.squeeze(x2, axis=1), [0, 2, 1])  # TensorShape([None, 8, 100])
    x = layers.concatenate([inp1, x2_reshaped], axis=1)
    x = layers.LSTM(32, activation='tanh',
                    # kernel_regularizer=tf.keras.regularizers.l1(0.001),
                    activity_regularizer=tf.keras.regularizers.l1(0.01)
                    )(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(8, activation='tanh',
                    kernel_regularizer=tf.keras.regularizers.l2(0.01),
                    activity_regularizer=tf.keras.regularizers.l2(0.01)
                    )(x)
    x = layers.Dropout(0.25)(x)
    x = layers.Dense(1, activation='sigmoid')(x)
    model = Model(inputs=[inp1, inp2], outputs=[x])

    # print("A1 : ", datetime.datetime.now())
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)

    model.compile(
        loss='binary_crossentropy',
        optimizer=opt,
        metrics=['acc']
    )

    train_inp_gaze = X_train[:, :1, :]
    train_inp_cond = X_train[:, 1:, :]
    val_inp_gaze = X_val[:, :1, :]
    val_inp_cond = X_val[:, 1:, :]



    his = model.fit(epochs=nepochs, verbose=0,
              x=[train_inp_gaze, train_inp_cond], y=np.array(y_train).astype('float'),
              validation_data = ([val_inp_gaze, val_inp_cond], np.array(y_val).astype('float')),
                    callbacks = callbacks)
    return model

# %%
import numpy as np
from sklearn.model_selection import LeavePGroupsOut, GroupShuffleSplit

# lpgo1 = LeavePGroupsOut(n_groups=10)
res_dict = {}
i = 0
d = []

import random
from numpy.random import seed
seed(1)
tf.random.set_seed(3)
# from tensorflow.keras.utils import set_random_seed
# set_random_seed(2)
c = 0
# num_iters = 2
for sen_type, sen_type_df in df.groupby("Sentence_type"):
    print("=====" , sen_type)
    groups1 = sen_type_df['Subject']
    for to_shuffle in [False, True]:
        res_dict_key = 'shuffled_iter' if to_shuffle else 'normal_iter'
        res_dict[sen_type] = {}
        res_dict[sen_type][res_dict_key] = {}
        for ne in [5,10,15,30,50,100]:
            # if 1==1:
            for num_iters in [50]:#,200]:#310,15,20,25,30,50,100]:
                for n_test_subjs in [2,5,10,20]:# [4,8,12,15,20]:
                    # num_iters = 15
                    # n_test_subjs = 8
                    c+=1
                    lpgo1 = GroupShuffleSplit(n_splits=num_iters, test_size=n_test_subjs, random_state = 7)
                    print(f"{datetime.datetime.now()} : Start - c = {c} ({ne, num_iters, n_test_subjs, to_shuffle}")
                    i = 0
                    for tmp_index, test_index in lpgo1.split(X = sen_type_df[timepoint_cols] , y = sen_type_df['phq_binary_label'], groups = groups1):
                        print(f"{datetime.datetime.now()}: Iter {i} (c={c})")
                        if i==num_iters:
                            break
                        res_dict[sen_type][res_dict_key][i] = {}
                        res_dict[sen_type][res_dict_key][i]["nepochs"] = ne
                        res_dict[sen_type][res_dict_key][i]["num_iters"] = num_iters
                        res_dict[sen_type][res_dict_key][i]["n_test_subjs"] = n_test_subjs
                        res_dict[sen_type][res_dict_key][i]["is_shuffle_iter"] = to_shuffle
                        # lpgo2 = LeavePGroupsOut(n_groups=10)
                        lpgo2 = GroupShuffleSplit(n_splits=num_iters, test_size=n_test_subjs, random_state = 7)
                        test_subjects = list(np.unique(groups1.iloc[test_index]))
                        test_df = sen_type_df.iloc[test_index]
                        tmp_df = sen_type_df.iloc[tmp_index]
                        groups2 = tmp_df['Subject']
                        for train_index, val_index in lpgo2.split(X = tmp_df[timepoint_cols] ,
                                                                  y = tmp_df['phq_binary_label'],
                                                                  groups = groups2):
                            train_subjects = list(np.unique(groups2.iloc[train_index]))
                            val_subjects = list(np.unique(groups2.iloc[val_index]))
                            train_df = tmp_df.iloc[train_index]
                            val_df = tmp_df.iloc[val_index]
                            break
                        X_train, y_train = generate_3d_ds(train_df)
                        X_test, y_test = generate_3d_ds(test_df)
                        X_val, y_val = generate_3d_ds(val_df)
                        if to_shuffle:
                            y_train = random.sample(y_train, len(y_train))
                            y_test = random.sample(y_test, len(y_test))
                            y_val = random.sample(y_val, len(y_val))
                        # print(X_train.shape, X_test.shape, X_val.shape)
                        # print(f"{datetime.datetime.now()}: {len(test_subjects)} Test subject : {test_subjects}")
                        # print(f"{datetime.datetime.now()}: {len(val_subjects)} Val subject : {val_subjects}")
                        # print(f"{datetime.datetime.now()}: {len(train_subjects)} Train subject : {train_subjects}")
                        # print(f"{datetime.datetime.now(): Train Fold #{i}}")
                        fold_model = train_fold(X_train, y_train, X_val, y_val , nepochs=ne)
                        fold_eval = fold_model.evaluate([X_test[:, :1, :], X_test[:, 1:, :]], np.array(y_test).astype('float'))
                        fold_test_pred = fold_model.predict([X_test[:, :1, :], X_test[:, 1:, :]])
                        # print("Test eval is " , fold_eval)
                        # res_dict[i]["his"] = fold_his
                        # res_dict[i]["trained_model"] = fold_model
                        res_dict[sen_type][res_dict_key][i]["eval"] = fold_eval[1]
                        res_dict[sen_type][res_dict_key][i]["test_subjects"] = test_subjects
                        res_dict[sen_type][res_dict_key][i]["test_pred"] = [x[0] for x in fold_test_pred]
                        # print("Shape of pred is " , fold_test_pred.shape)
                        res_dict[sen_type][res_dict_key][i]["per_subject_mean_pred"] = calc_per_subj_pred(fold_test_pred)
                        # print("Shape of per_subject_mean_pred" , res_dict[i]["per_subject_mean_pred"].shape)
                        # break
                        res_dict[sen_type][res_dict_key][i]["per_subject_mean_label"] = calc_per_subj_pred(y_test)
                        res_dict[sen_type][res_dict_key][i]["per_subject_is_success"] = [True if round(p)==round(t) else False for p,t in
                                                                 zip(res_dict[sen_type][res_dict_key][i]["per_subject_mean_pred"],
                                                                 res_dict[sen_type][res_dict_key][i]["per_subject_mean_label"])]
                        res_dict[sen_type][res_dict_key][i]["subj_level_acc"] = sum(res_dict[sen_type][res_dict_key][i]["per_subject_is_success"]) / \
                                                                      len(res_dict[sen_type][res_dict_key][i]["per_subject_is_success"])
                        i+=1

                    print(res_dict)
                    print(res_dict[sen_type])
                    print(res_dict[sen_type][res_dict_key])
                    conf_acc_1 = np.mean([res_dict[sen_type][res_dict_key][x]['eval'] for x in range(num_iters)])
                    conf_acc_2 = np.mean([res_dict[sen_type][res_dict_key][x]['subj_level_acc'] for x in range(num_iters)])
                    print(f"{datetime.datetime.now()} - c = {c} ({ne, num_iters, n_test_subjs, to_shuffle}) , accs are {conf_acc_1}, {conf_acc_2}")
                    d.append([num_iters, sen_type, ne, n_test_subjs, conf_acc_1, conf_acc_2, to_shuffle])
                    print(d)
                    print(pd.DataFrame(d))
print(f"{datetime.datetime.now()} Done")
res_df5 = pd.DataFrame(d , columns=["num_iters","sen_type", "num_epochs","num_test_subjs","eval","subj_acc","is_shuffle_iter"])
joblib.dump(res_df5, "./res_df_with_both_shuffle__freeze__fixed_PER_SENTENCE_TYPE.jbl")
joblib.dump(res_dict, "./res_dict_with_both_shuffle__freeze__fixed_PER_SENTENCE_TYPE.jbl")
# Out:
# ===== A
# 2022-07-14 09:40:48.796771 : Start - c = 1 ((5, 50, 2, False)
# 2022-07-14 09:40:48.799093: Iter 0 (c=1)
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8376 - acc: 0.4375
# 2022-07-14 09:40:57.065030: Iter 1 (c=1)
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9769 - acc: 0.5000
# 2022-07-14 09:41:04.525793: Iter 2 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0493 - acc: 0.5000
# 2022-07-14 09:41:11.941126: Iter 3 (c=1)
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8822 - acc: 0.3750
# 2022-07-14 09:41:19.430221: Iter 4 (c=1)
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0185 - acc: 0.3750
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0ff9894310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2022-07-14 09:41:26.992861: Iter 5 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8967 - acc: 0.1875
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f1015eb7d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2022-07-14 09:41:34.397829: Iter 6 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4523 - acc: 0.0625
# 2022-07-14 09:41:41.749571: Iter 7 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0424 - acc: 0.3125
# 2022-07-14 09:41:49.241035: Iter 8 (c=1)
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6578 - acc: 0.6875
# 2022-07-14 09:41:56.681333: Iter 9 (c=1)
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9546 - acc: 0.3125
# 2022-07-14 09:42:04.211761: Iter 10 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2240 - acc: 0.3125
# 2022-07-14 09:42:11.717833: Iter 11 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3355 - acc: 0.2500
# 2022-07-14 09:42:19.203517: Iter 12 (c=1)
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7131 - acc: 0.5000
# 2022-07-14 09:42:26.740231: Iter 13 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5627 - acc: 0.8750
# 2022-07-14 09:42:34.334964: Iter 14 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6970 - acc: 0.6250
# 2022-07-14 09:42:41.813539: Iter 15 (c=1)
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0602 - acc: 0.4375
# 2022-07-14 09:42:49.321635: Iter 16 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0344 - acc: 0.1875
# 2022-07-14 09:42:57.012679: Iter 17 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8469 - acc: 0.4375
# 2022-07-14 09:43:04.531868: Iter 18 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0516 - acc: 0.4375
# 2022-07-14 09:43:12.061264: Iter 19 (c=1)
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1095 - acc: 0.3125
# 2022-07-14 09:43:19.590148: Iter 20 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 1.1289 - acc: 0.1250
# 2022-07-14 09:43:27.090375: Iter 21 (c=1)
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9856 - acc: 0.5000
# 2022-07-14 09:43:34.700625: Iter 22 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9420 - acc: 0.6250
# 2022-07-14 09:43:42.396331: Iter 23 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6580 - acc: 0.6875
# 2022-07-14 09:43:49.871431: Iter 24 (c=1)
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9299 - acc: 0.4375
# 2022-07-14 09:43:57.272671: Iter 25 (c=1)
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6816 - acc: 0.6250
# 2022-07-14 09:44:04.838935: Iter 26 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8226 - acc: 0.5000
# 2022-07-14 09:44:12.337442: Iter 27 (c=1)
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0822 - acc: 0.3750
# 2022-07-14 09:44:19.862576: Iter 28 (c=1)
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9019 - acc: 0.3125
# 2022-07-14 09:44:27.423362: Iter 29 (c=1)
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8945 - acc: 0.3125
# 2022-07-14 09:44:34.967931: Iter 30 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9726 - acc: 0.5000
# 2022-07-14 09:44:42.531980: Iter 31 (c=1)
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8906 - acc: 0.4375
# 2022-07-14 09:44:50.214212: Iter 32 (c=1)
# 1/1 [==============================] - 0s 52ms/step - loss: 1.1012 - acc: 0.5000
# 2022-07-14 09:44:57.980393: Iter 33 (c=1)
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8025 - acc: 0.5625
# 2022-07-14 09:45:05.928766: Iter 34 (c=1)
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8225 - acc: 0.5625
# 2022-07-14 09:45:13.822912: Iter 35 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 0.7231 - acc: 0.6875
# 2022-07-14 09:45:21.937128: Iter 36 (c=1)
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0464 - acc: 0.5000
# 2022-07-14 09:45:29.678439: Iter 37 (c=1)
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7664 - acc: 0.6250
# 2022-07-14 09:45:37.971261: Iter 38 (c=1)
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6223 - acc: 0.8125
# 2022-07-14 09:45:46.308679: Iter 39 (c=1)
# 1/1 [==============================] - 0s 49ms/step - loss: 0.8204 - acc: 0.5000
# 2022-07-14 09:45:54.755751: Iter 40 (c=1)
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9769 - acc: 0.3750
# 2022-07-14 09:46:03.333645: Iter 41 (c=1)
# 1/1 [==============================] - 0s 50ms/step - loss: 0.9914 - acc: 0.4375
# 2022-07-14 09:46:10.981309: Iter 42 (c=1)
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7100 - acc: 0.6250
# 2022-07-14 09:46:19.174873: Iter 43 (c=1)
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9787 - acc: 0.2500
# 2022-07-14 09:46:27.943701: Iter 44 (c=1)
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9011 - acc: 0.5625
# 2022-07-14 09:46:36.513943: Iter 45 (c=1)
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6873 - acc: 0.6875
# 2022-07-14 09:46:45.086313: Iter 46 (c=1)
# 1/1 [==============================] - 0s 49ms/step - loss: 0.8100 - acc: 0.5000
# 2022-07-14 09:46:53.808945: Iter 47 (c=1)
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0165 - acc: 0.3750
# 2022-07-14 09:47:02.349108: Iter 48 (c=1)
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8772 - acc: 0.5625
# 2022-07-14 09:47:10.128767: Iter 49 (c=1)
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6516 - acc: 0.6875
# {'A': {'normal_iter': {0: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [47, 59], 'test_pred': [0.71250767, 0.45495126, 0.2856032, 0.54772824, 0.6003311, 0.626242, 0.61507463, 0.6003311, 0.66954345, 0.8078283, 0.17155173, 0.56286025, 0.2849402, 0.26478168, 0.38481364, 0.27502647], 'per_subject_mean_pred': 0    0.491507
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 1: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [77, 115], 'test_pred': [0.4650947, 0.40008998, 0.5532716, 0.40008998, 0.21106687, 0.21424766, 0.5008002, 0.19729963, 0.15839311, 0.63052726, 0.24234496, 0.112898685, 0.29493582, 0.68230903, 0.36704326, 0.17224619], 'per_subject_mean_pred': 0    0.350166
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 2: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [127, 128], 'test_pred': [0.3980131, 0.72636485, 0.48187417, 0.7064485, 0.6767829, 0.4379029, 0.7159428, 0.72636485, 0.5469414, 0.21210618, 0.55808276, 0.5612443, 0.19611481, 0.6045524, 0.21724805, 0.55808276], 'per_subject_mean_pred': 0    0.520254
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 3: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [81, 109], 'test_pred': [0.19606298, 0.42132056, 0.5937289, 0.3545864, 0.39585173, 0.22624727, 0.49455348, 0.5627881, 0.6812208, 0.733024, 0.59628105, 0.5845066, 0.65968364, 0.7184098, 0.64985675, 0.56013274], 'per_subject_mean_pred': 0    0.526766
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 4: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [95, 96], 'test_pred': [0.2625328, 0.48496667, 0.5518044, 0.73906475, 0.16393217, 0.7284923, 0.32775426, 0.17422418, 0.48619545, 0.5784185, 0.41028354, 0.19206686, 0.5402286, 0.60352, 0.30327564, 0.45286193], 'per_subject_mean_pred': 0    0.437476
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 5: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.1875, 'test_subjects': [82, 106], 'test_pred': [0.6570897, 0.23873281, 0.5334669, 0.58676714, 0.38767263, 0.5334669, 0.38732517, 0.5061859, 0.6970826, 0.52415943, 0.5240761, 0.6542513, 0.5159934, 0.6542513, 0.56840634, 0.7028704], 'per_subject_mean_pred': 0    0.541987
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 6: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.0625, 'test_subjects': [48, 80], 'test_pred': [0.1689333, 0.4022327, 0.12158046, 0.2016564, 0.19502392, 0.19940141, 0.182164, 0.19745451, 0.22668596, 0.5481622, 0.1844965, 0.39421976, 0.315178, 0.2877111, 0.36983064, 0.48761997], 'per_subject_mean_pred': 0    0.280147
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 7: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [70, 95], 'test_pred': [0.81454563, 0.24377543, 0.3621362, 0.7014917, 0.569728, 0.54911166, 0.46057767, 0.61506784, 0.21480127, 0.3400737, 0.46282384, 0.65547127, 0.1742798, 0.62619424, 0.4184792, 0.18902965], 'per_subject_mean_pred': 0    0.462349
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 8: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.6875, 'test_subjects': [46, 113], 'test_pred': [0.22827615, 0.23534133, 0.39401042, 0.303505, 0.7066759, 0.61322725, 0.60972804, 0.50884855, 0.43713954, 0.18256757, 0.41679144, 0.45190072, 0.304282, 0.32151356, 0.3247018, 0.6074973], 'per_subject_mean_pred': 0    0.415375
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 9: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [30, 81], 'test_pred': [0.7859563, 0.7804682, 0.5095721, 0.6286471, 0.27832985, 0.5125615, 0.32723045, 0.7360773, 0.6338021, 0.61892414, 0.6019567, 0.4570133, 0.38973936, 0.25992417, 0.712171, 0.58964694], 'per_subject_mean_pred': 0    0.551376
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 10: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [3, 55], 'test_pred': [0.4127646, 0.7150826, 0.7775153, 0.67580014, 0.82693607, 0.18484773, 0.7173016, 0.6617435, 0.231062, 0.16223514, 0.19416621, 0.7112787, 0.7979405, 0.16223514, 0.19416621, 0.7112787], 'per_subject_mean_pred': 0    0.508522
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 11: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.25, 'test_subjects': [101, 134], 'test_pred': [0.510782, 0.63446283, 0.22722645, 0.13992119, 0.5042614, 0.59419465, 0.32254323, 0.40005624, 0.785925, 0.81723535, 0.767043, 0.7612386, 0.7698655, 0.8131242, 0.65172946, 0.8200391], 'per_subject_mean_pred': 0    0.594978
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 12: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [34, 119], 'test_pred': [0.30678242, 0.5466786, 0.44363222, 0.71008134, 0.3177414, 0.5039952, 0.35614735, 0.77168566, 0.15616155, 0.14359392, 0.21045901, 0.5588968, 0.5524884, 0.5872891, 0.20837872, 0.5872891], 'per_subject_mean_pred': 0    0.435081
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 13: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.875, 'test_subjects': [17, 110], 'test_pred': [0.5776695, 0.36218992, 0.22689933, 0.4251168, 0.61477375, 0.33255103, 0.37572375, 0.30523783, 0.6941712, 0.58942175, 0.71483004, 0.6665596, 0.6635834, 0.58942175, 0.6941712, 0.6509079], 'per_subject_mean_pred': 0    0.530202
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 14: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [70, 108], 'test_pred': [0.81205666, 0.15986104, 0.3049561, 0.574074, 0.35084713, 0.5075166, 0.2330403, 0.5296891, 0.29523897, 0.24444468, 0.6155714, 0.46847394, 0.56229955, 0.29523897, 0.3362324, 0.48080155], 'per_subject_mean_pred': 0    0.423146
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 15: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [30, 32], 'test_pred': [0.88107896, 0.8715455, 0.7960234, 0.878497, 0.62649757, 0.643676, 0.3000653, 0.60689473, 0.80769664, 0.4404758, 0.7790701, 0.8122785, 0.7013811, 0.7086602, 0.17587996, 0.7635031], 'per_subject_mean_pred': 0    0.674576
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 16: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.1875, 'test_subjects': [69, 117], 'test_pred': [0.6034257, 0.741641, 0.76629466, 0.62651515, 0.6613284, 0.6201173, 0.65846014, 0.74763364, 0.5069947, 0.44124424, 0.59716624, 0.60412204, 0.77435386, 0.37709427, 0.5069947, 0.34199443], 'per_subject_mean_pred': 0    0.598461
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 17: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [90, 137], 'test_pred': [0.29325715, 0.43565357, 0.6552516, 0.5821126, 0.358675, 0.356012, 0.73608625, 0.59623855, 0.5478084, 0.6748715, 0.22229, 0.66515154, 0.37196016, 0.6259085, 0.32668558, 0.7226012], 'per_subject_mean_pred': 0    0.51066
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 18: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [48, 131], 'test_pred': [0.19762853, 0.27291027, 0.30576977, 0.311349, 0.20033798, 0.19222479, 0.14689374, 0.24805175, 0.3453214, 0.3097845, 0.522905, 0.3097845, 0.37826398, 0.39370313, 0.34628856, 0.20040277], 'per_subject_mean_pred': 0    0.292601
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 19: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [126, 132], 'test_pred': [0.6546307, 0.5414854, 0.22314265, 0.39800644, 0.44476795, 0.16572441, 0.3870643, 0.37193513, 0.4207684, 0.18268923, 0.7298681, 0.22093411, 0.18268923, 0.5726375, 0.553728, 0.29844025], 'per_subject_mean_pred': 0    0.396782
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 20: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.125, 'test_subjects': [4, 121], 'test_pred': [0.80440253, 0.81683654, 0.7634809, 0.62015414, 0.553335, 0.6041808, 0.6801544, 0.5119713, 0.80912656, 0.6122065, 0.66788155, 0.3469074, 0.3464913, 0.67303294, 0.6122065, 0.5359536], 'per_subject_mean_pred': 0    0.622395
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 21: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [97, 139], 'test_pred': [0.19916245, 0.49238652, 0.19916245, 0.19235584, 0.6523776, 0.6172861, 0.5923366, 0.42650667, 0.5204706, 0.4842778, 0.14983904, 0.3475233, 0.53012913, 0.69913375, 0.53460115, 0.56928796], 'per_subject_mean_pred': 0    0.450427
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 22: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [35, 90], 'test_pred': [0.23848471, 0.5140337, 0.66443104, 0.6025086, 0.23848471, 0.56826186, 0.58905923, 0.575951, 0.3353828, 0.2725062, 0.506509, 0.6783023, 0.22597389, 0.21018028, 0.57137555, 0.59482676], 'per_subject_mean_pred': 0    0.461642
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 23: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.6875, 'test_subjects': [34, 120], 'test_pred': [0.39276215, 0.3076877, 0.2556362, 0.56373954, 0.2584982, 0.5737575, 0.2246791, 0.7259415, 0.44728428, 0.3996562, 0.34831536, 0.59926724, 0.6725705, 0.18320315, 0.29706788, 0.2924414], 'per_subject_mean_pred': 0    0.408907
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 24: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [32, 69], 'test_pred': [0.75239795, 0.32788447, 0.79387575, 0.79376245, 0.68022394, 0.6204063, 0.26380914, 0.5728295, 0.5019185, 0.7663074, 0.7529416, 0.69868606, 0.6464504, 0.41010854, 0.7178025, 0.7425592], 'per_subject_mean_pred': 0    0.627623
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 25: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [127, 135], 'test_pred': [0.6289401, 0.41536784, 0.46263167, 0.48023248, 0.59869725, 0.42228198, 0.5246964, 0.41536784, 0.554395, 0.15784541, 0.4084911, 0.31007788, 0.3221786, 0.38979694, 0.50885004, 0.5112278], 'per_subject_mean_pred': 0    0.444442
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 26: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [5, 96], 'test_pred': [0.5910845, 0.48635972, 0.42774805, 0.1448153, 0.596057, 0.46984348, 0.5154279, 0.7146073, 0.48172385, 0.71175367, 0.47914046, 0.16852988, 0.5091577, 0.56519485, 0.4021872, 0.6403457], 'per_subject_mean_pred': 0    0.493999
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 27: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [58, 93], 'test_pred': [0.36617765, 0.39326712, 0.535826, 0.19858038, 0.3684032, 0.535826, 0.34944344, 0.18850312, 0.71120226, 0.6499634, 0.6282641, 0.4840708, 0.4208886, 0.15070912, 0.605213, 0.10896132], 'per_subject_mean_pred': 0    0.418456
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 28: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [82, 109], 'test_pred': [0.5470541, 0.11297777, 0.5136221, 0.59203666, 0.3816575, 0.5136221, 0.42628473, 0.5852329, 0.65292853, 0.78045744, 0.31646448, 0.78282374, 0.6486736, 0.6284282, 0.6759736, 0.2980744], 'per_subject_mean_pred': 0    0.528519
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 29: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [11, 97], 'test_pred': [0.1829287, 0.2607545, 0.42725703, 0.42629373, 0.48839533, 0.41029733, 0.4432905, 0.4923345, 0.46351534, 0.5701075, 0.46351534, 0.569453, 0.5330711, 0.5408028, 0.7520876, 0.3176988], 'per_subject_mean_pred': 0    0.458863
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 30: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [50, 136], 'test_pred': [0.31557566, 0.7573091, 0.2965093, 0.59023356, 0.7567681, 0.31880066, 0.19476907, 0.26661342, 0.24420202, 0.16267484, 0.55553865, 0.49315813, 0.55857897, 0.5442188, 0.64964473, 0.5683767], 'per_subject_mean_pred': 0    0.454561
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 31: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [11, 103], 'test_pred': [0.13683012, 0.40907404, 0.5508432, 0.63989305, 0.45019767, 0.44894043, 0.5237803, 0.5089077, 0.36790326, 0.43073788, 0.36790326, 0.685717, 0.5911727, 0.37632158, 0.551426, 0.3951178], 'per_subject_mean_pred': 0    0.464673
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 32: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [93, 128], 'test_pred': [0.68677247, 0.6757803, 0.73466635, 0.5579462, 0.62083, 0.32557383, 0.67018807, 0.09624669, 0.4755202, 0.12878482, 0.30575976, 0.5174458, 0.17258503, 0.7488879, 0.10009689, 0.30575976], 'per_subject_mean_pred': 0    0.445178
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 33: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5625, 'test_subjects': [84, 89], 'test_pred': [0.6657206, 0.5106723, 0.46410927, 0.70009243, 0.7303924, 0.74177355, 0.68926924, 0.7451173, 0.8055187, 0.68871635, 0.2684568, 0.39364284, 0.62179804, 0.62883186, 0.6181621, 0.74110955], 'per_subject_mean_pred': 0    0.625836
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 34: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5625, 'test_subjects': [94, 95], 'test_pred': [0.46642536, 0.6324786, 0.21100503, 0.56681377, 0.6776141, 0.72606146, 0.66908205, 0.40744528, 0.4362766, 0.4899668, 0.56061214, 0.6967709, 0.14754274, 0.67449963, 0.5956888, 0.3156363], 'per_subject_mean_pred': 0    0.51712
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 35: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.6875, 'test_subjects': [34, 84], 'test_pred': [0.2943443, 0.47716692, 0.5093265, 0.7678226, 0.17447084, 0.31670907, 0.45734066, 0.7941103, 0.56152064, 0.60748494, 0.34206942, 0.64312917, 0.49309146, 0.78788614, 0.63310814, 0.63329905], 'per_subject_mean_pred': 0    0.530805
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 36: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [4, 14], 'test_pred': [0.791949, 0.8487973, 0.84469086, 0.71834147, 0.66351604, 0.79589224, 0.6777798, 0.7616464, 0.69458395, 0.64315385, 0.60846716, 0.5650904, 0.7484217, 0.6588831, 0.77506983, 0.59695226], 'per_subject_mean_pred': 0    0.712077
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 37: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [17, 80], 'test_pred': [0.8160723, 0.07368452, 0.29544598, 0.3945377, 0.7897238, 0.5893333, 0.43802372, 0.34282, 0.30060363, 0.7779211, 0.4571727, 0.8882843, 0.74234724, 0.30625916, 0.69913524, 0.6219453], 'per_subject_mean_pred': 0    0.533332
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 38: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.8125, 'test_subjects': [42, 100], 'test_pred': [0.33876467, 0.3204972, 0.2690362, 0.3619503, 0.22353467, 0.17977323, 0.5746333, 0.49173975, 0.11637317, 0.73952186, 0.35054874, 0.085779764, 0.83629537, 0.33878562, 0.15121008, 0.4704762], 'per_subject_mean_pred': 0    0.365558
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 39: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [22, 107], 'test_pred': [0.3942293, 0.62657547, 0.5165244, 0.409685, 0.61398065, 0.53202564, 0.37964708, 0.41569415, 0.35826987, 0.4612873, 0.6365574, 0.6172772, 0.6365574, 0.42675027, 0.34391445, 0.6507886], 'per_subject_mean_pred': 0    0.501235
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 40: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [4, 67], 'test_pred': [0.78438115, 0.8403253, 0.8152515, 0.6248556, 0.5027252, 0.79976356, 0.748331, 0.56301296, 0.7213202, 0.7044533, 0.4432802, 0.47109628, 0.5930819, 0.79194975, 0.679248, 0.72137237], 'per_subject_mean_pred': 0    0.675278
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 41: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [90, 121], 'test_pred': [0.14469945, 0.21378794, 0.7928001, 0.8273573, 0.4026385, 0.23055041, 0.73812187, 0.7566068, 0.76416546, 0.66459215, 0.4320016, 0.46396378, 0.41860843, 0.656265, 0.66459215, 0.6928649], 'per_subject_mean_pred': 0    0.553976
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 42: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [12, 120], 'test_pred': [0.5177308, 0.49698183, 0.6862263, 0.74123615, 0.5959412, 0.8006715, 0.57164246, 0.34746838, 0.6058918, 0.57041746, 0.7114064, 0.3085604, 0.7031766, 0.1597891, 0.44961822, 0.2891526], 'per_subject_mean_pred': 0    0.534744
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 43: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.25, 'test_subjects': [69, 122], 'test_pred': [0.4842616, 0.50788224, 0.5934221, 0.54010755, 0.460972, 0.4065414, 0.46773687, 0.5591422, 0.34801912, 0.24552037, 0.33736473, 0.25524408, 0.30298138, 0.48061588, 0.38264066, 0.33360478], 'per_subject_mean_pred': 0    0.419129
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 44: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5625, 'test_subjects': [64, 78], 'test_pred': [0.86217666, 0.64448434, 0.8840788, 0.4931255, 0.27250016, 0.6892513, 0.7402496, 0.29428974, 0.13133709, 0.201672, 0.7608809, 0.337332, 0.5892437, 0.16643302, 0.14811759, 0.337332], 'per_subject_mean_pred': 0    0.472032
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 45: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.6875, 'test_subjects': [5, 14], 'test_pred': [0.44314906, 0.7067736, 0.2740469, 0.14570257, 0.7007218, 0.5919534, 0.5173247, 0.6599306, 0.5767781, 0.67014027, 0.7332501, 0.6250917, 0.5463138, 0.7177511, 0.6817766, 0.6329305], 'per_subject_mean_pred': 0    0.576477
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 46: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [96, 116], 'test_pred': [0.54893446, 0.6553009, 0.49434516, 0.22749966, 0.57584816, 0.48002437, 0.4619242, 0.3185869, 0.6464044, 0.5224339, 0.7243188, 0.43980488, 0.50870556, 0.537178, 0.46635586, 0.364792], 'per_subject_mean_pred': 0    0.498279
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 47: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [35, 124], 'test_pred': [0.24329051, 0.6008836, 0.23591056, 0.35073385, 0.24329051, 0.5553957, 0.7068853, 0.7693424, 0.63556296, 0.7040982, 0.73959213, 0.16962302, 0.27261856, 0.73959213, 0.6887866, 0.7040982], 'per_subject_mean_pred': 0    0.522482
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 48: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5625, 'test_subjects': [35, 100], 'test_pred': [0.29279754, 0.6352279, 0.52830607, 0.6158092, 0.29279754, 0.54418015, 0.55240977, 0.584742, 0.19993871, 0.7380197, 0.6938514, 0.23257789, 0.75320035, 0.6487914, 0.3723432, 0.6724366], 'per_subject_mean_pred': 0    0.522339
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 49: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.6875, 'test_subjects': [17, 29], 'test_pred': [0.4682807, 0.13285919, 0.52061576, 0.31131113, 0.74489856, 0.6161453, 0.5953041, 0.49774417, 0.8075307, 0.75356466, 0.7110314, 0.32841197, 0.76083606, 0.80162805, 0.6242111, 0.79751515], 'per_subject_mean_pred': 0    0.591993
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}}}}
# {'normal_iter': {0: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [47, 59], 'test_pred': [0.71250767, 0.45495126, 0.2856032, 0.54772824, 0.6003311, 0.626242, 0.61507463, 0.6003311, 0.66954345, 0.8078283, 0.17155173, 0.56286025, 0.2849402, 0.26478168, 0.38481364, 0.27502647], 'per_subject_mean_pred': 0    0.491507
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 1: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [77, 115], 'test_pred': [0.4650947, 0.40008998, 0.5532716, 0.40008998, 0.21106687, 0.21424766, 0.5008002, 0.19729963, 0.15839311, 0.63052726, 0.24234496, 0.112898685, 0.29493582, 0.68230903, 0.36704326, 0.17224619], 'per_subject_mean_pred': 0    0.350166
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 2: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [127, 128], 'test_pred': [0.3980131, 0.72636485, 0.48187417, 0.7064485, 0.6767829, 0.4379029, 0.7159428, 0.72636485, 0.5469414, 0.21210618, 0.55808276, 0.5612443, 0.19611481, 0.6045524, 0.21724805, 0.55808276], 'per_subject_mean_pred': 0    0.520254
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 3: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [81, 109], 'test_pred': [0.19606298, 0.42132056, 0.5937289, 0.3545864, 0.39585173, 0.22624727, 0.49455348, 0.5627881, 0.6812208, 0.733024, 0.59628105, 0.5845066, 0.65968364, 0.7184098, 0.64985675, 0.56013274], 'per_subject_mean_pred': 0    0.526766
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 4: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [95, 96], 'test_pred': [0.2625328, 0.48496667, 0.5518044, 0.73906475, 0.16393217, 0.7284923, 0.32775426, 0.17422418, 0.48619545, 0.5784185, 0.41028354, 0.19206686, 0.5402286, 0.60352, 0.30327564, 0.45286193], 'per_subject_mean_pred': 0    0.437476
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 5: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.1875, 'test_subjects': [82, 106], 'test_pred': [0.6570897, 0.23873281, 0.5334669, 0.58676714, 0.38767263, 0.5334669, 0.38732517, 0.5061859, 0.6970826, 0.52415943, 0.5240761, 0.6542513, 0.5159934, 0.6542513, 0.56840634, 0.7028704], 'per_subject_mean_pred': 0    0.541987
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 6: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.0625, 'test_subjects': [48, 80], 'test_pred': [0.1689333, 0.4022327, 0.12158046, 0.2016564, 0.19502392, 0.19940141, 0.182164, 0.19745451, 0.22668596, 0.5481622, 0.1844965, 0.39421976, 0.315178, 0.2877111, 0.36983064, 0.48761997], 'per_subject_mean_pred': 0    0.280147
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 7: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [70, 95], 'test_pred': [0.81454563, 0.24377543, 0.3621362, 0.7014917, 0.569728, 0.54911166, 0.46057767, 0.61506784, 0.21480127, 0.3400737, 0.46282384, 0.65547127, 0.1742798, 0.62619424, 0.4184792, 0.18902965], 'per_subject_mean_pred': 0    0.462349
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 8: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.6875, 'test_subjects': [46, 113], 'test_pred': [0.22827615, 0.23534133, 0.39401042, 0.303505, 0.7066759, 0.61322725, 0.60972804, 0.50884855, 0.43713954, 0.18256757, 0.41679144, 0.45190072, 0.304282, 0.32151356, 0.3247018, 0.6074973], 'per_subject_mean_pred': 0    0.415375
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 9: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [30, 81], 'test_pred': [0.7859563, 0.7804682, 0.5095721, 0.6286471, 0.27832985, 0.5125615, 0.32723045, 0.7360773, 0.6338021, 0.61892414, 0.6019567, 0.4570133, 0.38973936, 0.25992417, 0.712171, 0.58964694], 'per_subject_mean_pred': 0    0.551376
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 10: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [3, 55], 'test_pred': [0.4127646, 0.7150826, 0.7775153, 0.67580014, 0.82693607, 0.18484773, 0.7173016, 0.6617435, 0.231062, 0.16223514, 0.19416621, 0.7112787, 0.7979405, 0.16223514, 0.19416621, 0.7112787], 'per_subject_mean_pred': 0    0.508522
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 11: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.25, 'test_subjects': [101, 134], 'test_pred': [0.510782, 0.63446283, 0.22722645, 0.13992119, 0.5042614, 0.59419465, 0.32254323, 0.40005624, 0.785925, 0.81723535, 0.767043, 0.7612386, 0.7698655, 0.8131242, 0.65172946, 0.8200391], 'per_subject_mean_pred': 0    0.594978
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 12: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [34, 119], 'test_pred': [0.30678242, 0.5466786, 0.44363222, 0.71008134, 0.3177414, 0.5039952, 0.35614735, 0.77168566, 0.15616155, 0.14359392, 0.21045901, 0.5588968, 0.5524884, 0.5872891, 0.20837872, 0.5872891], 'per_subject_mean_pred': 0    0.435081
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 13: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.875, 'test_subjects': [17, 110], 'test_pred': [0.5776695, 0.36218992, 0.22689933, 0.4251168, 0.61477375, 0.33255103, 0.37572375, 0.30523783, 0.6941712, 0.58942175, 0.71483004, 0.6665596, 0.6635834, 0.58942175, 0.6941712, 0.6509079], 'per_subject_mean_pred': 0    0.530202
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 14: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [70, 108], 'test_pred': [0.81205666, 0.15986104, 0.3049561, 0.574074, 0.35084713, 0.5075166, 0.2330403, 0.5296891, 0.29523897, 0.24444468, 0.6155714, 0.46847394, 0.56229955, 0.29523897, 0.3362324, 0.48080155], 'per_subject_mean_pred': 0    0.423146
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 15: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [30, 32], 'test_pred': [0.88107896, 0.8715455, 0.7960234, 0.878497, 0.62649757, 0.643676, 0.3000653, 0.60689473, 0.80769664, 0.4404758, 0.7790701, 0.8122785, 0.7013811, 0.7086602, 0.17587996, 0.7635031], 'per_subject_mean_pred': 0    0.674576
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 16: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.1875, 'test_subjects': [69, 117], 'test_pred': [0.6034257, 0.741641, 0.76629466, 0.62651515, 0.6613284, 0.6201173, 0.65846014, 0.74763364, 0.5069947, 0.44124424, 0.59716624, 0.60412204, 0.77435386, 0.37709427, 0.5069947, 0.34199443], 'per_subject_mean_pred': 0    0.598461
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 17: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [90, 137], 'test_pred': [0.29325715, 0.43565357, 0.6552516, 0.5821126, 0.358675, 0.356012, 0.73608625, 0.59623855, 0.5478084, 0.6748715, 0.22229, 0.66515154, 0.37196016, 0.6259085, 0.32668558, 0.7226012], 'per_subject_mean_pred': 0    0.51066
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 18: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [48, 131], 'test_pred': [0.19762853, 0.27291027, 0.30576977, 0.311349, 0.20033798, 0.19222479, 0.14689374, 0.24805175, 0.3453214, 0.3097845, 0.522905, 0.3097845, 0.37826398, 0.39370313, 0.34628856, 0.20040277], 'per_subject_mean_pred': 0    0.292601
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 19: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [126, 132], 'test_pred': [0.6546307, 0.5414854, 0.22314265, 0.39800644, 0.44476795, 0.16572441, 0.3870643, 0.37193513, 0.4207684, 0.18268923, 0.7298681, 0.22093411, 0.18268923, 0.5726375, 0.553728, 0.29844025], 'per_subject_mean_pred': 0    0.396782
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 20: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.125, 'test_subjects': [4, 121], 'test_pred': [0.80440253, 0.81683654, 0.7634809, 0.62015414, 0.553335, 0.6041808, 0.6801544, 0.5119713, 0.80912656, 0.6122065, 0.66788155, 0.3469074, 0.3464913, 0.67303294, 0.6122065, 0.5359536], 'per_subject_mean_pred': 0    0.622395
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 21: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [97, 139], 'test_pred': [0.19916245, 0.49238652, 0.19916245, 0.19235584, 0.6523776, 0.6172861, 0.5923366, 0.42650667, 0.5204706, 0.4842778, 0.14983904, 0.3475233, 0.53012913, 0.69913375, 0.53460115, 0.56928796], 'per_subject_mean_pred': 0    0.450427
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 22: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [35, 90], 'test_pred': [0.23848471, 0.5140337, 0.66443104, 0.6025086, 0.23848471, 0.56826186, 0.58905923, 0.575951, 0.3353828, 0.2725062, 0.506509, 0.6783023, 0.22597389, 0.21018028, 0.57137555, 0.59482676], 'per_subject_mean_pred': 0    0.461642
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 23: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.6875, 'test_subjects': [34, 120], 'test_pred': [0.39276215, 0.3076877, 0.2556362, 0.56373954, 0.2584982, 0.5737575, 0.2246791, 0.7259415, 0.44728428, 0.3996562, 0.34831536, 0.59926724, 0.6725705, 0.18320315, 0.29706788, 0.2924414], 'per_subject_mean_pred': 0    0.408907
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 24: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [32, 69], 'test_pred': [0.75239795, 0.32788447, 0.79387575, 0.79376245, 0.68022394, 0.6204063, 0.26380914, 0.5728295, 0.5019185, 0.7663074, 0.7529416, 0.69868606, 0.6464504, 0.41010854, 0.7178025, 0.7425592], 'per_subject_mean_pred': 0    0.627623
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 25: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.625, 'test_subjects': [127, 135], 'test_pred': [0.6289401, 0.41536784, 0.46263167, 0.48023248, 0.59869725, 0.42228198, 0.5246964, 0.41536784, 0.554395, 0.15784541, 0.4084911, 0.31007788, 0.3221786, 0.38979694, 0.50885004, 0.5112278], 'per_subject_mean_pred': 0    0.444442
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 26: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [5, 96], 'test_pred': [0.5910845, 0.48635972, 0.42774805, 0.1448153, 0.596057, 0.46984348, 0.5154279, 0.7146073, 0.48172385, 0.71175367, 0.47914046, 0.16852988, 0.5091577, 0.56519485, 0.4021872, 0.6403457], 'per_subject_mean_pred': 0    0.493999
# dtype: float64, 'per_subject_mean_label': 0    0.5
# dtype: float64, 'per_subject_is_success': [True], 'subj_level_acc': 1.0}, 27: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.375, 'test_subjects': [58, 93], 'test_pred': [0.36617765, 0.39326712, 0.535826, 0.19858038, 0.3684032, 0.535826, 0.34944344, 0.18850312, 0.71120226, 0.6499634, 0.6282641, 0.4840708, 0.4208886, 0.15070912, 0.605213, 0.10896132], 'per_subject_mean_pred': 0    0.418456
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 28: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [82, 109], 'test_pred': [0.5470541, 0.11297777, 0.5136221, 0.59203666, 0.3816575, 0.5136221, 0.42628473, 0.5852329, 0.65292853, 0.78045744, 0.31646448, 0.78282374, 0.6486736, 0.6284282, 0.6759736, 0.2980744], 'per_subject_mean_pred': 0    0.528519
# dtype: float64, 'per_subject_mean_label': 0    0.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 29: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.3125, 'test_subjects': [11, 97], 'test_pred': [0.1829287, 0.2607545, 0.42725703, 0.42629373, 0.48839533, 0.41029733, 0.4432905, 0.4923345, 0.46351534, 0.5701075, 0.46351534, 0.569453, 0.5330711, 0.5408028, 0.7520876, 0.3176988], 'per_subject_mean_pred': 0    0.458863
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 30: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [50, 136], 'test_pred': [0.31557566, 0.7573091, 0.2965093, 0.59023356, 0.7567681, 0.31880066, 0.19476907, 0.26661342, 0.24420202, 0.16267484, 0.55553865, 0.49315813, 0.55857897, 0.5442188, 0.64964473, 0.5683767], 'per_subject_mean_pred': 0    0.454561
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 31: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [11, 103], 'test_pred': [0.13683012, 0.40907404, 0.5508432, 0.63989305, 0.45019767, 0.44894043, 0.5237803, 0.5089077, 0.36790326, 0.43073788, 0.36790326, 0.685717, 0.5911727, 0.37632158, 0.551426, 0.3951178], 'per_subject_mean_pred': 0    0.464673
# dtype: float64, 'per_subject_mean_label': 0    1.0
# dtype: float64, 'per_subject_is_success': [False], 'subj_level_acc': 0.0}, 32: {'nepochs': 5, 'num_iters': 50, 'n_test_subjs': 2, 'is_shuffle_iter': False, 'eval': 0.5, 'test_subjects': [93, 128], 'test_pred': [0.68677247, 0.6757803, 0.73466635, 0.5579462, 0.62083, 0.32557383, 0.67018807, 0.09624669, 0.4755202, 0.12878482, 0.30575976, 0.5174458, 0.17258503, 0.7488879, 0.10009689, 0.30575976], 'per_subject_mean_pred': 0    0.445178
# ...
# 1    0.506354
# 2    0.391650
# dtype: float64, 'per_subject_mean_label': 0    0.75
# 1    0.25
# 2    1.00
# dtype: float64, 'per_subject_is_success': [True, False, False], 'subj_level_acc': 0.3333333333333333}, 43: {'nepochs': 30, 'num_iters': 50, 'n_test_subjs': 10, 'is_shuffle_iter': False, 'eval': 0.44999998807907104, 'test_subjects': [29, 42, 48, 49, 69, 80, 96, 122, 125, 137], 'test_pred': [0.77476984, 0.73571604, 0.7531724, 0.51028514, 0.7670705, 0.70794827, 0.72033304, 0.78338337, 0.50116295, 0.62723666, 0.47668007, 0.6503908, 0.27254304, 0.36180538, 0.7376236, 0.643673, 0.26974502, 0.17146073, 0.1879308, 0.5760667, 0.5601329, 0.34538004, 0.18974005, 0.16913272, 0.5852681, 0.2117022, 0.50801015, 0.51268446, 0.22785015, 0.26326913, 0.42023098, 0.1835848, 0.651738, 0.5120356, 0.53766495, 0.6223811, 0.24037158, 0.5289023, 0.6480498, 0.73351526, 0.1503648, 0.41927007, 0.37034935, 0.6934172, 0.44900522, 0.36761212, 0.45492285, 0.62562054, 0.70488316, 0.5239504, 0.6114133, 0.23286304, 0.29714793, 0.61790913, 0.5672018, 0.42867047, 0.22317566, 0.15185152, 0.34947303, 0.1768386, 0.1535919, 0.37465975, 0.40515178, 0.1661272, 0.32299754, 0.18228482, 0.53978205, 0.76352465, 0.23338127, 0.3545872, 0.16484976, 0.59191126, 0.1979168, 0.637861, 0.13907817, 0.5843713, 0.19258395, 0.5866599, 0.1824954, 0.4248226], 'per_subject_mean_pred': 0    0.481437
# 1    0.437192
# 2    0.381194
# dtype: float64, 'per_subject_mean_label': 0    0.50
# 1    0.75
# 2    0.00
# dtype: float64, 'per_subject_is_success': [True, False, True], 'subj_level_acc': 0.6666666666666666}, 44: {'nepochs': 30, 'num_iters': 50, 'n_test_subjs': 10, 'is_shuffle_iter': False, 'eval': 0.32499998807907104, 'test_subjects': [46, 62, 64, 69, 78, 82, 88, 125, 126, 139], 'test_pred': [0.4930773, 0.51135594, 0.5052741, 0.5169974, 0.5229118, 0.52585816, 0.5287785, 0.51415294, 0.505864, 0.5135027, 0.507078, 0.4956977, 0.48988795, 0.5067232, 0.49812782, 0.48988795, 0.52490294, 0.54468143, 0.515696, 0.5305003, 0.5125108, 0.583441, 0.5331497, 0.52386713, 0.5066366, 0.5201492, 0.52662295, 0.51363367, 0.5101559, 0.5208341, 0.56589997, 0.5716643, 0.4764209, 0.5176983, 0.57526463, 0.5242418, 0.51469463, 0.48791605, 0.46905407, 0.5242418, 0.560097, 0.48813182, 0.54705256, 0.52072877, 0.4883722, 0.54705256, 0.48988447, 0.5503391, 0.53214794, 0.5119775, 0.5665233, 0.5406231, 0.5065235, 0.5489613, 0.5522704, 0.5165018, 0.51925325, 0.5105085, 0.53039557, 0.52732253, 0.4918559, 0.5236164, 0.48187134, 0.54964834, 0.5206233, 0.53346, 0.5037, 0.5256412, 0.50504255, 0.47747678, 0.5222063, 0.52341413, 0.50230396, 0.554159, 0.47908905, 0.5431021, 0.52877563, 0.5428891, 0.5947753, 0.4869807], 'per_subject_mean_pred': 0    0.519673
# 1    0.521600
# 2    0.521477
# dtype: float64, 'per_subject_mean_label': 0    0.0
# 1    0.0
# 2    1.0
# dtype: float64, 'per_subject_is_success': [False, False, True], 'subj_level_acc': 0.3333333333333333}, 45: {'nepochs': 30, 'num_iters': 50, 'n_test_subjs': 10, 'is_shuffle_iter': False, 'eval': 0.5874999761581421, 'test_subjects': [5, 14, 32, 53, 54, 59, 67, 95, 100, 106], 'test_pred': [0.4695853, 0.51270086, 0.46654013, 0.43334985, 0.48357698, 0.47726548, 0.44306704, 0.48606068, 0.4844969, 0.48958772, 0.51764095, 0.45864716, 0.515738, 0.51588356, 0.47259098, 0.47850364, 0.48204228, 0.44824463, 0.5283738, 0.537104, 0.482068, 0.509057, 0.4760087, 0.44132334, 0.49852937, 0.5114578, 0.4874173, 0.47560734, 0.50200844, 0.48864478, 0.49094233, 0.5094703, 0.49538678, 0.5316557, 0.5054155, 0.49088994, 0.4620406, 0.46885085, 0.46427563, 0.52929586, 0.47613537, 0.49221873, 0.4770345, 0.4746087, 0.46879938, 0.484473, 0.49672616, 0.48589918, 0.47707418, 0.47409165, 0.48241982, 0.44950604, 0.4767983, 0.5146896, 0.47642702, 0.50169337, 0.4544784, 0.46187374, 0.48370737, 0.47264087, 0.4560732, 0.45639473, 0.46643713, 0.44498074, 0.45625153, 0.47238457, 0.48808467, 0.42686388, 0.4980526, 0.5287602, 0.43248263, 0.4741699, 0.5346273, 0.4630691, 0.45521742, 0.45395505, 0.49566427, 0.45395505, 0.44457296, 0.48944342], 'per_subject_mean_pred': 0    0.486673
# 1    0.479781
# 2    0.472972
# dtype: float64, 'per_subject_mean_label': 0    0.5
# 1    0.5
# 2    0.0
# dtype: float64, 'per_subject_is_success': [True, True, True], 'subj_level_acc': 1.0}, 46: {'nepochs': 30, 'num_iters': 50, 'n_test_subjs': 10, 'is_shuffle_iter': False, 'eval': 0.4375, 'test_subjects': [3, 4, 35, 63, 72, 82, 96, 99, 116, 124], 'test_pred': [0.46569547, 0.59730613, 0.6232932, 0.5631433, 0.6318531, 0.47810563, 0.47972184, 0.56367666, 0.5182828, 0.53070235, 0.5927489, 0.5899781, 0.47614583, 0.49760953, 0.5171575, 0.4824445, 0.46769097, 0.50658727, 0.56018513, 0.50191027, 0.46769097, 0.5593806, 0.5914599, 0.5258752, 0.45346573, 0.5018673, 0.53531754, 0.45122644, 0.5023938, 0.53531754, 0.4781175, 0.56992346, 0.49763358, 0.4857023, 0.55387133, 0.5782377, 0.40958065, 0.57710105, 0.48749334, 0.5073687, 0.47531638, 0.46531534, 0.5083957, 0.49359143, 0.42895272, 0.5083957, 0.4289348, 0.4846982, 0.45593017, 0.4661931, 0.5591596, 0.4675576, 0.55643666, 0.46187943, 0.54423666, 0.43029037, 0.4510157, 0.4276303, 0.45708552, 0.44536886, 0.45369774, 0.44132966, 0.4522182, 0.43212894, 0.55091345, 0.45458004, 0.49188945, 0.4524297, 0.45941344, 0.486386, 0.44175577, 0.4561655, 0.47542146, 0.5233632, 0.47108755, 0.40567282, 0.44166225, 0.47108755, 0.49646676, 0.5233632], 'per_subject_mean_pred': 0    0.525509
# 1    0.481023
# 2    0.475104
# dtype: float64, 'per_subject_mean_label': 0    0.25
# 1    0.50
# 2    0.50
# dtype: float64, 'per_subject_is_success': [False, True, True], 'subj_level_acc': 0.6666666666666666}, 47: {'nepochs': 30, 'num_iters': 50, 'n_test_subjs': 10, 'is_shuffle_iter': False, 'eval': 0.5375000238418579, 'test_subjects': [5, 7, 30, 31, 35, 83, 103, 105, 122, 124], 'test_pred': [0.46327093, 0.41039306, 0.47074816, 0.39668962, 0.42585057, 0.47383425, 0.43452492, 0.4415689, 0.46005476, 0.49412036, 0.5129978, 0.50005215, 0.5380579, 0.4982354, 0.491857, 0.5164876, 0.5522885, 0.5354991, 0.50354916, 0.5931543, 0.45071116, 0.44648707, 0.43031177, 0.52125967, 0.50104254, 0.46301666, 0.47598246, 0.4965233, 0.53649163, 0.48133394, 0.50762373, 0.4754932, 0.46003774, 0.4541462, 0.5084719, 0.476097, 0.46003774, 0.47371972, 0.5283572, 0.5234436, 0.47142246, 0.44964132, 0.5123939, 0.46632326, 0.50294626, 0.4970167, 0.49712062, 0.53414905, 0.42587155, 0.44354406, 0.42587155, 0.5034955, 0.45260996, 0.4719509, 0.4841962, 0.44802314, 0.46811554, 0.42539823, 0.4812559, 0.44217187, 0.37401307, 0.40558448, 0.42539823, 0.44990575, 0.4812533, 0.46890107, 0.47367865, 0.47051, 0.42047065, 0.5042699, 0.5022853, 0.45251885, 0.41982642, 0.48014316, 0.49443612, 0.3983514, 0.4171974, 0.49443612, 0.48464864, 0.48014316], 'per_subject_mean_pred': 0    0.484360
# 1    0.466960
# 2    0.465192
# dtype: float64, 'per_subject_mean_label': 0    0.50
# 1    0.75
# 2    0.50
# dtype: float64, 'per_subject_is_success': [True, False, True], 'subj_level_acc': 0.6666666666666666}, 48: {'nepochs': 30, 'num_iters': 50, 'n_test_subjs': 10, 'is_shuffle_iter': False, 'eval': 0.48750001192092896, 'test_subjects': [25, 35, 51, 62, 66, 88, 100, 110, 111, 122], 'test_pred': [0.5187998, 0.41916332, 0.4108157, 0.46573523, 0.42146444, 0.58025527, 0.4480421, 0.54045725, 0.33974987, 0.5099439, 0.41826454, 0.46106702, 0.33974987, 0.4439839, 0.5750417, 0.5446684, 0.5417832, 0.555773, 0.4568492, 0.5248015, 0.41696995, 0.4727023, 0.5862695, 0.622118, 0.40810937, 0.38783926, 0.3416475, 0.4019141, 0.3768152, 0.48733112, 0.50930715, 0.3768152, 0.43911317, 0.452427, 0.43911317, 0.41796538, 0.4348464, 0.452427, 0.4464176, 0.35534933, 0.52371204, 0.37587762, 0.5843345, 0.4450666, 0.4670969, 0.53218, 0.51398957, 0.44307688, 0.35353696, 0.3941297, 0.42795238, 0.40403003, 0.46571016, 0.41931668, 0.39559206, 0.4561659, 0.5617193, 0.46076488, 0.60730237, 0.3326118, 0.35453394, 0.46076488, 0.5617193, 0.46432343, 0.43964648, 0.34382173, 0.41281432, 0.45869887, 0.46898168, 0.42707813, 0.45535278, 0.41826153, 0.45867762, 0.3441771, 0.4259904, 0.36714247, 0.33274356, 0.4861064, 0.4951706, 0.4228579], 'per_subject_mean_pred': 0    0.465758
# 1    0.451349
# 2    0.422345
# dtype: float64, 'per_subject_mean_label': 0    0.50
# 1    0.25
# 2    1.00
# dtype: float64, 'per_subject_is_success': [True, True, False], 'subj_level_acc': 0.6666666666666666}, 49: {'nepochs': 30, 'num_iters': 50, 'n_test_subjs': 10, 'is_shuffle_iter': False, 'eval': 0.5375000238418579, 'test_subjects': [17, 29, 34, 54, 59, 105, 115, 119, 120, 133], 'test_pred': [0.49136773, 0.38412428, 0.45384738, 0.45205826, 0.5724735, 0.52752537, 0.4544667, 0.47036648, 0.6343572, 0.54693085, 0.57435906, 0.5177602, 0.5755978, 0.56431943, 0.5979716, 0.6437328, 0.47263384, 0.49794307, 0.43968096, 0.6776563, 0.46174031, 0.36829132, 0.42259896, 0.44669288, 0.5160045, 0.47172084, 0.37009472, 0.38882506, 0.46189147, 0.50596666, 0.34466997, 0.47072577, 0.6231773, 0.6346957, 0.40861034, 0.59789085, 0.51723003, 0.5006597, 0.5903883, 0.52845395, 0.5142412, 0.34945112, 0.5421795, 0.25630182, 0.4361478, 0.43797734, 0.34945112, 0.55582196, 0.3930065, 0.5723481, 0.5190981, 0.31224266, 0.4142169, 0.4462541, 0.45271167, 0.40524817, 0.48662922, 0.47467765, 0.46658766, 0.51725453, 0.5383299, 0.44191605, 0.5315722, 0.44191605, 0.5589592, 0.64136493, 0.6620819, 0.6089802, 0.5457174, 0.4518594, 0.5928464, 0.5914235, 0.34243047, 0.3811644, 0.32379463, 0.6307276, 0.37291571, 0.35296214, 0.23468758, 0.50361705], 'per_subject_mean_pred': 0    0.493075
# 1    0.476771
# 2    0.487221
# dtype: float64, 'per_subject_mean_label': 0    0.25
# 1    0.25
# 2    0.50
# dtype: float64, 'per_subject_is_success': [True, True, True], 'subj_level_acc': 1.0}}
# 2022-07-14 11:34:57.317196 - c = 15 ((30, 50, 10, False)) , accs are 0.4784999996423721, 0.5466666666666666
# [[50, 'A', 5, 2, 0.4675, 0.28, False], [50, 'A', 5, 5, 0.5029999977350235, 0.49, False], [50, 'A', 5, 10, 0.4912499976158142, 0.48666666666666664, False], [50, 'A', 5, 20, 0.4807499998807907, 0.47600000000000003, False], [50, 'A', 10, 2, 0.5125, 0.48, False], [50, 'A', 10, 5, 0.5469999957084656, 0.48, False], [50, 'A', 10, 10, 0.5159999984502792, 0.5133333333333333, False], [50, 'A', 10, 20, 0.5110000026226044, 0.524, False], [50, 'A', 15, 2, 0.53, 0.5, False], [50, 'A', 15, 5, 0.5449999976158142, 0.6, False], [50, 'A', 15, 10, 0.5357499998807908, 0.5133333333333333, False], [50, 'A', 15, 20, 0.5160000038146972, 0.568, False], [50, 'A', 30, 2, 0.4225, 0.5, False], [50, 'A', 30, 5, 0.47350000381469726, 0.45, False], [50, 'A', 30, 10, 0.4784999996423721, 0.5466666666666666, False]]
#      0  1   2   3        4         5      6
# 0   50  A   5   2  0.46750  0.280000  False
# 1   50  A   5   5  0.50300  0.490000  False
# 2   50  A   5  10  0.49125  0.486667  False
# 3   50  A   5  20  0.48075  0.476000  False
# 4   50  A  10   2  0.51250  0.480000  False
# 5   50  A  10   5  0.54700  0.480000  False
# 6   50  A  10  10  0.51600  0.513333  False
# 7   50  A  10  20  0.51100  0.524000  False
# 8   50  A  15   2  0.53000  0.500000  False
# 9   50  A  15   5  0.54500  0.600000  False
# 10  50  A  15  10  0.53575  0.513333  False
# 11  50  A  15  20  0.51600  0.568000  False
# 12  50  A  30   2  0.42250  0.500000  False
# 13  50  A  30   5  0.47350  0.450000  False
# 14  50  A  30  10  0.47850  0.546667  False
# 2022-07-14 11:34:57.320161 : Start - c = 16 ((30, 50, 20, False)
# 2022-07-14 11:34:57.323363: Iter 0 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8020 - acc: 0.5188
# 2022-07-14 11:35:07.281400: Iter 1 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7786 - acc: 0.4437
# 2022-07-14 11:35:17.028256: Iter 2 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8294 - acc: 0.3938
# 2022-07-14 11:35:26.771702: Iter 3 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7930 - acc: 0.5125
# 2022-07-14 11:35:36.342418: Iter 4 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8696 - acc: 0.4187
# 2022-07-14 11:35:45.615082: Iter 5 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8721 - acc: 0.4313
# 2022-07-14 11:35:55.326218: Iter 6 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7964 - acc: 0.5000
# 2022-07-14 11:36:04.920941: Iter 7 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8231 - acc: 0.4625
# 2022-07-14 11:36:14.598060: Iter 8 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8155 - acc: 0.4812
# 2022-07-14 11:36:24.083005: Iter 9 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8146 - acc: 0.5375
# 2022-07-14 11:36:33.427712: Iter 10 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8056 - acc: 0.4938
# 2022-07-14 11:36:43.430193: Iter 11 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7840 - acc: 0.5375
# 2022-07-14 11:36:52.917998: Iter 12 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7897 - acc: 0.5000
# 2022-07-14 11:37:02.276082: Iter 13 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7997 - acc: 0.4563
# 2022-07-14 11:37:11.914785: Iter 14 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8033 - acc: 0.5250
# 2022-07-14 11:37:21.431445: Iter 15 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8013 - acc: 0.4187
# 2022-07-14 11:37:31.105753: Iter 16 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7862 - acc: 0.5750
# 2022-07-14 11:37:41.767646: Iter 17 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7909 - acc: 0.4125
# 2022-07-14 11:37:52.431462: Iter 18 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7962 - acc: 0.4563
# 2022-07-14 11:38:02.819055: Iter 19 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8754 - acc: 0.3875
# 2022-07-14 11:38:14.176621: Iter 20 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8190 - acc: 0.4187
# 2022-07-14 11:38:25.032795: Iter 21 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8002 - acc: 0.5188
# 2022-07-14 11:38:36.136245: Iter 22 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7933 - acc: 0.5125
# 2022-07-14 11:38:47.227289: Iter 23 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7909 - acc: 0.4812
# 2022-07-14 11:38:58.300757: Iter 24 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8135 - acc: 0.3938
# 2022-07-14 11:39:09.608110: Iter 25 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8739 - acc: 0.4812
# 2022-07-14 11:39:20.946145: Iter 26 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7972 - acc: 0.4187
# 2022-07-14 11:39:31.961969: Iter 27 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8159 - acc: 0.4812
# 2022-07-14 11:39:41.802690: Iter 28 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8100 - acc: 0.5437
# 2022-07-14 11:39:51.707256: Iter 29 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0484 - acc: 0.5125
# 2022-07-14 11:40:02.442018: Iter 30 (c=16)
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7956 - acc: 0.4875
# 2022-07-14 11:40:12.604523: Iter 31 (c=16)
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0313 - acc: 0.4313
# 2022-07-14 11:40:23.473385: Iter 32 (c=16)
